# %% [markdown]
# # Systems Check
# ## Alex Buckler
# ### 8/22/2024
#
# In this class I would like to understand more about __python__. Since I am in the EMAT field I want to understand more about different _computer systems_ and programs. I already have experience with these coding formats:
# 1. html
# 2. p5
#
# ![thumbs](data:image/jpeg;base64,...)
